# %% [markdown]
# # Import necessary libraries

# %%
#Install libraries
# !pip install transformers
# !pip install sentencepiece
# !pip install textattack


#Import libraries
import pandas as pd
import pickle
from transformers import MarianMTModel, MarianTokenizer
from textattack.augmentation import WordNetAugmenter, EmbeddingAugmenter, EasyDataAugmenter, CharSwapAugmenter, CheckListAugmenter, CLAREAugmenter

import pp
# Out:
# Requirement already satisfied: transformers in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (4.30.2)
# Requirement already satisfied: filelock in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from requests->transformers) (2023.5.7)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sentencepiece in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (0.1.99)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: textattack in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (0.3.9)
# Requirement already satisfied: bert-score>=0.3.5 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (0.3.13)
# Requirement already satisfied: editdistance in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (0.6.2)
# Requirement already satisfied: flair in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (0.13.1)
# Requirement already satisfied: filelock in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (3.12.2)
# Requirement already satisfied: language-tool-python in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (2.7.1)
# Requirement already satisfied: lemminflect in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (0.2.3)
# Requirement already satisfied: lru-dict in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (1.3.0)
# Requirement already satisfied: datasets>=2.4.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (2.16.1)
# Requirement already satisfied: nltk in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (3.8.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (1.24.3)
# Requirement already satisfied: pandas>=1.0.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (2.0.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (1.11.1)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (2.1.0.dev20230717)
# Requirement already satisfied: transformers>=4.30.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (4.30.2)
# Requirement already satisfied: terminaltables in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (3.1.10)
# Requirement already satisfied: tqdm in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (4.65.0)
# Requirement already satisfied: word2number in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (1.1)
# Requirement already satisfied: num2words in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (0.5.13)
# Requirement already satisfied: more-itertools in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (10.2.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (1.7.1)
# Requirement already satisfied: pinyin>=0.4.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (0.4.0)
# Requirement already satisfied: jieba in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (0.42.1)
# Requirement already satisfied: OpenHowNet in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (2.0)
# Requirement already satisfied: pycld2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (0.41)
# Requirement already satisfied: click<8.1.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from textattack) (8.0.4)
# Requirement already satisfied: requests in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from bert-score>=0.3.5->textattack) (2.31.0)
# Requirement already satisfied: matplotlib in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from bert-score>=0.3.5->textattack) (3.7.2)
# Requirement already satisfied: packaging>=20.9 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from bert-score>=0.3.5->textattack) (23.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (0.3.7)
# Requirement already satisfied: xxhash in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (2023.6.0)
# Requirement already satisfied: aiohttp in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from datasets>=2.4.0->textattack) (6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from pandas>=1.0.1->textattack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from pandas>=1.0.1->textattack) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from pandas>=1.0.1->textattack) (2023.3)
# Requirement already satisfied: typing-extensions in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from torch!=1.8,>=1.7.0->textattack) (4.5.0)
# Requirement already satisfied: sympy in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from torch!=1.8,>=1.7.0->textattack) (1.12)
# Requirement already satisfied: networkx in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from torch!=1.8,>=1.7.0->textattack) (3.1)
# Requirement already satisfied: jinja2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from torch!=1.8,>=1.7.0->textattack) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers>=4.30.0->textattack) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers>=4.30.0->textattack) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers>=4.30.0->textattack) (0.3.1)
# Requirement already satisfied: boto3>=1.20.27 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (1.28.3)
# Requirement already satisfied: bpemb>=0.3.2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (0.3.4)
# Requirement already satisfied: conllu>=4.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (4.5.3)
# Requirement already satisfied: deprecated>=1.2.13 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (1.2.14)
# Requirement already satisfied: ftfy>=6.1.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (6.1.3)
# Requirement already satisfied: gdown>=4.4.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (5.0.0)
# Requirement already satisfied: gensim>=4.2.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (4.3.2)
# Requirement already satisfied: janome>=0.4.2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (0.5.0)
# Requirement already satisfied: langdetect>=1.0.9 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (1.0.9)
# Requirement already satisfied: lxml>=4.8.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (4.9.3)
# Requirement already satisfied: mpld3>=0.3 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (0.5.10)
# Requirement already satisfied: pptree>=3.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (3.1)
# Requirement already satisfied: pytorch-revgrad>=0.2.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (0.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (1.3.0)
# Requirement already satisfied: segtok>=1.5.11 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (1.5.11)
# Requirement already satisfied: sqlitedict>=2.0.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (2.1.0)
# Requirement already satisfied: tabulate>=0.8.10 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (0.9.0)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.3 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (0.3.3)
# Requirement already satisfied: urllib3<2.0.0,>=1.0.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (1.26.15)
# Requirement already satisfied: wikipedia-api>=0.5.7 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (0.6.0)
# Requirement already satisfied: semver<4.0.0,>=3.0.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from flair->textattack) (3.0.2)
# Requirement already satisfied: joblib in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from nltk->textattack) (1.3.0)
# Requirement already satisfied: docopt>=0.6.2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from num2words->textattack) (0.6.2)
# Requirement already satisfied: anytree in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from OpenHowNet->textattack) (2.12.1)
# Requirement already satisfied: setuptools in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from OpenHowNet->textattack) (68.0.0)
# Requirement already satisfied: botocore<1.32.0,>=1.31.3 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from boto3>=1.20.27->flair->textattack) (1.31.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from boto3>=1.20.27->flair->textattack) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from boto3>=1.20.27->flair->textattack) (0.6.1)
# Requirement already satisfied: sentencepiece in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from bpemb>=0.3.2->flair->textattack) (0.1.99)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from deprecated>=1.2.13->flair->textattack) (1.15.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from aiohttp->datasets>=2.4.0->textattack) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from aiohttp->datasets>=2.4.0->textattack) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from aiohttp->datasets>=2.4.0->textattack) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from aiohttp->datasets>=2.4.0->textattack) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from aiohttp->datasets>=2.4.0->textattack) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from aiohttp->datasets>=2.4.0->textattack) (4.0.3)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from ftfy>=6.1.0->flair->textattack) (0.2.13)
# Requirement already satisfied: beautifulsoup4 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from gdown>=4.4.0->flair->textattack) (4.12.2)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from gensim>=4.2.0->flair->textattack) (6.3.0)
# Requirement already satisfied: six in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from langdetect>=1.0.9->flair->textattack) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from matplotlib->bert-score>=0.3.5->textattack) (6.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from requests->bert-score>=0.3.5->textattack) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from requests->bert-score>=0.3.5->textattack) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from requests->bert-score>=0.3.5->textattack) (2023.5.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from scikit-learn>=1.0.2->flair->textattack) (3.2.0)
# Requirement already satisfied: protobuf<=3.20.3 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers>=4.30.0->textattack) (3.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from jinja2->torch!=1.8,>=1.7.0->textattack) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from sympy->torch!=1.8,>=1.7.0->textattack) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->bert-score>=0.3.5->textattack) (3.16.2)
# Requirement already satisfied: accelerate>=0.20.2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from transformers>=4.30.0->textattack) (0.26.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from beautifulsoup4->gdown>=4.4.0->flair->textattack) (2.3.2.post1)
# Requirement already satisfied: psutil in /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages (from accelerate>=0.20.2->transformers>=4.30.0->textattack) (5.9.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
#English to french model
en2french = 'Helsinki-NLP/opus-mt-en-fr'
en2french_tkn = MarianTokenizer.from_pretrained(en2french)
en2french_model = MarianMTModel.from_pretrained(en2french)

#french to english model
french2en = 'Helsinki-NLP/opus-mt-fr-en'
french2en_tkn = MarianTokenizer.from_pretrained(french2en)
french2en_model = MarianMTModel.from_pretrained(french2en)
# Out:
# /Users/meetbanthia/miniconda3/envs/torch/lib/python3.9/site-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
original_texts = ["THE NEW PIECEGOODS BAZAR CO., LTD.,BOMBAY vs THE COMMISSIONER OF INCOME-TAX,BOMBAY on 26 May, 1950 ",
          "Equivalent citations: 1950 AIR 165, 1950 SCR 553 ",
          "The first model translates from English to French, which is a temporary process", 
          "The second model finally translates back all the temporary french text into English"]

original_texts
# Out:
# ['THE NEW PIECEGOODS BAZAR CO., LTD.,BOMBAY vs THE COMMISSIONER OF INCOME-TAX,BOMBAY on 26 May, 1950 ',
#  'Equivalent citations: 1950 AIR 165, 1950 SCR 553 ',
#  'The first model translates from English to French, which is a temporary process',
#  'The second model finally translates back all the temporary french text into English']

# %%
#bring the texts to format for the model
def format_batch_texts(language_code, batch_texts):
  
    formated_bach = [">>{}<< {}".format(language_code, text) for text in batch_texts]

    return formated_bach

#performs translation
def perform_translation(batch_texts, model, tokenizer, language="fr"):
    # Prepare the text data into appropriate format for the model
    formated_batch_texts = format_batch_texts(language, batch_texts)
    
    # Generate translation using model
    translated = model.generate(**tokenizer(formated_batch_texts, return_tensors="pt", padding=True),max_new_tokens=200)

    # Convert the generated tokens indices back into text
    translated_texts = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
    
    return translated_texts

# translated_texts = perform_translation(original_texts, en2french_model, en2french_tkn)

# %% [markdown]
# # Backtranslation

# %%
def perform_back_translation(batch_texts, original_language="en", temporary_language="fr"):

  # Translate from Original to Temporary Language
  tmp_translated_batch = perform_translation(batch_texts, en2french_model, en2french_tkn, temporary_language)

  # Translate Back to English
  back_translated_batch = perform_translation(tmp_translated_batch, french2en_model, french2en_tkn, original_language)

  # Return The Final Result
  return back_translated_batch

# %% [markdown]
# # Backtranslation with augmentation

# %%
def combine_texts(original_texts, back_translated_batch):
  
  return set(original_texts + back_translated_batch) 

def perform_back_translation_with_augmentation(batch_texts, original_language="en", temporary_language="fr"):

 # Translate from Original to Temporary Language
  tmp_translated_batch = perform_translation(batch_texts, en2french_model, en2french_tkn, temporary_language)

  # Translate Back to English
  back_translated_batch = perform_translation(tmp_translated_batch, french2en_model, french2en_tkn, original_language)

  # Return The Final Result
  return combine_texts(original_texts, back_translated_batch)

# %% [markdown]
# # Work on dataset

# %%
df = pd.read_csv('final.csv',sep=',',names=['label','sentence'])
df = df.drop(0)

label_counts = df['label'].value_counts()
print(label_counts)

#Remove labels which is occuring more than 240 times in final.csv
df = df.drop(df[df['label'] == 'RPC'].index)
df = df.drop(df[df['label'] == 'PRECEDENT'].index)
df = df.drop(df[df['label'] == 'REASONING'].index)
df = df.drop(df[df['label'] == 'FACTS'].index)
# Out:
# label
# REASONING    3291
# FACTS        1458
# PRECEDENT     271
# RPC           242
# STATUTE       176
# RLC           171
# COUNSEL       128
# ARG           121
# JUDGE          64
# CITATION       60
# NAME           59
# Name: count, dtype: int64

# %%
# rows_to_delete = df[df['label'] == 'REASONING']
# rows_to_keep = 3051
# selected_rows = rows_to_delete.sample(n=rows_to_keep, random_state=42)
# df = df.drop(selected_rows.index)

# %%
# Analyse the frequency of each labels

label_counts = df['label'].value_counts()
print(label_counts)
# Out:
# label
# STATUTE     176
# RLC         171
# COUNSEL     128
# ARG         121
# JUDGE        64
# CITATION     60
# NAME         59
# Name: count, dtype: int64

# %%
#storing df sentences into a list tmp
tmp = (df.values).tolist()
tmp = [item[1] for item in tmp]

# %% [markdown]
# # Perform back translation on dataframe list tmp

# %%
back = []
sz = len(tmp)
for sent in tmp:
    dum = perform_back_translation([sent])
    back.extend(dum)
    sz = sz-1
    print(f"{sz} sentences left")
# Out:
# 778 sentences left
# 777 sentences left
# 776 sentences left
# 775 sentences left
# 774 sentences left
# 773 sentences left
# 772 sentences left
# 771 sentences left
# 770 sentences left
# 769 sentences left
# 768 sentences left
# 767 sentences left
# 766 sentences left
# 765 sentences left
# 764 sentences left
# 763 sentences left
# 762 sentences left
# 761 sentences left
# 760 sentences left
# 759 sentences left
# 758 sentences left
# 757 sentences left
# 756 sentences left
# 755 sentences left
# 754 sentences left
# 753 sentences left
# 752 sentences left
# 751 sentences left
# 750 sentences left
# 749 sentences left
# 748 sentences left
# 747 sentences left
# 746 sentences left
# 745 sentences left
# 744 sentences left
# 743 sentences left
# 742 sentences left
# 741 sentences left
# 740 sentences left
# 739 sentences left
# 738 sentences left
# 737 sentences left
# 736 sentences left
# 735 sentences left
# 734 sentences left
# 733 sentences left
# 732 sentences left
# 731 sentences left
# 730 sentences left
# 729 sentences left
# 728 sentences left
# 727 sentences left
# 726 sentences left
# 725 sentences left
# 724 sentences left
# 723 sentences left
# 722 sentences left
# 721 sentences left
# 720 sentences left
# 719 sentences left
# 718 sentences left
# 717 sentences left
# 716 sentences left
# 715 sentences left
# 714 sentences left
# 713 sentences left
# 712 sentences left
# 711 sentences left
# 710 sentences left
# 709 sentences left
# 708 sentences left
# 707 sentences left
# 706 sentences left
# 705 sentences left
# 704 sentences left
# 703 sentences left
# 702 sentences left
# 701 sentences left
# 700 sentences left
# 699 sentences left
# 698 sentences left
# 697 sentences left
# 696 sentences left
# 695 sentences left
# 694 sentences left
# 693 sentences left
# 692 sentences left
# 691 sentences left
# 690 sentences left
# 689 sentences left
# 688 sentences left
# 687 sentences left
# 686 sentences left
# 685 sentences left
# 684 sentences left
# 683 sentences left
# 682 sentences left
# 681 sentences left
# 680 sentences left
# 679 sentences left
# 678 sentences left
# 677 sentences left
# 676 sentences left
# 675 sentences left
# 674 sentences left
# 673 sentences left
# 672 sentences left
# 671 sentences left
# 670 sentences left
# 669 sentences left
# 668 sentences left
# 667 sentences left
# 666 sentences left
# 665 sentences left
# 664 sentences left
# 663 sentences left
# 662 sentences left
# 661 sentences left
# 660 sentences left
# 659 sentences left
# 658 sentences left
# 657 sentences left
# 656 sentences left
# 655 sentences left
# 654 sentences left
# 653 sentences left
# 652 sentences left
# 651 sentences left
# 650 sentences left
# 649 sentences left
# 648 sentences left
# 647 sentences left
# 646 sentences left
# 645 sentences left
# 644 sentences left
# 643 sentences left
# 642 sentences left
# 641 sentences left
# 640 sentences left
# 639 sentences left
# 638 sentences left
# 637 sentences left
# 636 sentences left
# 635 sentences left
# 634 sentences left
# 633 sentences left
# 632 sentences left
# 631 sentences left
# 630 sentences left
# 629 sentences left
# 628 sentences left
# 627 sentences left
# 626 sentences left
# 625 sentences left
# 624 sentences left
# 623 sentences left
# 622 sentences left
# 621 sentences left
# 620 sentences left
# 619 sentences left
# 618 sentences left
# 617 sentences left
# 616 sentences left
# 615 sentences left
# 614 sentences left
# 613 sentences left
# 612 sentences left
# 611 sentences left
# 610 sentences left
# 609 sentences left
# 608 sentences left
# 607 sentences left
# 606 sentences left
# 605 sentences left
# 604 sentences left
# 603 sentences left
# 602 sentences left
# 601 sentences left
# 600 sentences left
# 599 sentences left
# 598 sentences left
# 597 sentences left
# 596 sentences left
# 595 sentences left
# 594 sentences left
# 593 sentences left
# 592 sentences left
# 591 sentences left
# 590 sentences left
# 589 sentences left
# 588 sentences left
# 587 sentences left
# 586 sentences left
# 585 sentences left
# 584 sentences left
# 583 sentences left
# 582 sentences left
# 581 sentences left
# 580 sentences left
# 579 sentences left
# 578 sentences left
# 577 sentences left
# 576 sentences left
# 575 sentences left
# 574 sentences left
# 573 sentences left
# 572 sentences left
# 571 sentences left
# 570 sentences left
# 569 sentences left
# 568 sentences left
# 567 sentences left
# 566 sentences left
# 565 sentences left
# 564 sentences left
# 563 sentences left
# 562 sentences left
# 561 sentences left
# 560 sentences left
# 559 sentences left
# 558 sentences left
# 557 sentences left
# 556 sentences left
# 555 sentences left
# 554 sentences left
# 553 sentences left
# 552 sentences left
# 551 sentences left
# 550 sentences left
# 549 sentences left
# 548 sentences left
# 547 sentences left
# 546 sentences left
# 545 sentences left
# 544 sentences left
# 543 sentences left
# 542 sentences left
# 541 sentences left
# 540 sentences left
# 539 sentences left
# 538 sentences left
# 537 sentences left
# 536 sentences left
# 535 sentences left
# 534 sentences left
# 533 sentences left
# 532 sentences left
# 531 sentences left
# 530 sentences left
# 529 sentences left
# 528 sentences left
# 527 sentences left
# 526 sentences left
# 525 sentences left
# 524 sentences left
# 523 sentences left
# 522 sentences left
# 521 sentences left
# 520 sentences left
# 519 sentences left
# 518 sentences left
# 517 sentences left
# 516 sentences left
# 515 sentences left
# 514 sentences left
# 513 sentences left
# 512 sentences left
# 511 sentences left
# 510 sentences left
# 509 sentences left
# 508 sentences left
# 507 sentences left
# 506 sentences left
# 505 sentences left
# 504 sentences left
# 503 sentences left
# 502 sentences left
# 501 sentences left
# 500 sentences left
# 499 sentences left
# 498 sentences left
# 497 sentences left
# 496 sentences left
# 495 sentences left
# 494 sentences left
# 493 sentences left
# 492 sentences left
# 491 sentences left
# 490 sentences left
# 489 sentences left
# 488 sentences left
# 487 sentences left
# 486 sentences left
# 485 sentences left
# 484 sentences left
# 483 sentences left
# 482 sentences left
# 481 sentences left
# 480 sentences left
# 479 sentences left
# 478 sentences left
# 477 sentences left
# 476 sentences left
# 475 sentences left
# 474 sentences left
# 473 sentences left
# 472 sentences left
# 471 sentences left
# 470 sentences left
# 469 sentences left
# 468 sentences left
# 467 sentences left
# 466 sentences left
# 465 sentences left
# 464 sentences left
# 463 sentences left
# 462 sentences left
# 461 sentences left
# 460 sentences left
# 459 sentences left
# 458 sentences left
# 457 sentences left
# 456 sentences left
# 455 sentences left
# 454 sentences left
# 453 sentences left
# 452 sentences left
# 451 sentences left
# 450 sentences left
# 449 sentences left
# 448 sentences left
# 447 sentences left
# 446 sentences left
# 445 sentences left
# 444 sentences left
# 443 sentences left
# 442 sentences left
# 441 sentences left
# 440 sentences left
# 439 sentences left
# 438 sentences left
# 437 sentences left
# 436 sentences left
# 435 sentences left
# 434 sentences left
# 433 sentences left
# 432 sentences left
# 431 sentences left
# 430 sentences left
# 429 sentences left
# 428 sentences left
# 427 sentences left
# 426 sentences left
# 425 sentences left
# 424 sentences left
# 423 sentences left
# 422 sentences left
# 421 sentences left
# 420 sentences left
# 419 sentences left
# 418 sentences left
# 417 sentences left
# 416 sentences left
# 415 sentences left
# 414 sentences left
# 413 sentences left
# 412 sentences left
# 411 sentences left
# 410 sentences left
# 409 sentences left
# 408 sentences left
# 407 sentences left
# 406 sentences left
# 405 sentences left
# 404 sentences left
# 403 sentences left
# 402 sentences left
# 401 sentences left
# 400 sentences left
# 399 sentences left
# 398 sentences left
# 397 sentences left
# 396 sentences left
# 395 sentences left
# 394 sentences left
# 393 sentences left
# 392 sentences left
# 391 sentences left
# 390 sentences left
# 389 sentences left
# 388 sentences left
# 387 sentences left
# 386 sentences left
# 385 sentences left
# 384 sentences left
# 383 sentences left
# 382 sentences left
# 381 sentences left
# 380 sentences left
# 379 sentences left
# 378 sentences left
# 377 sentences left
# 376 sentences left
# 375 sentences left
# 374 sentences left
# 373 sentences left
# 372 sentences left
# 371 sentences left
# 370 sentences left
# 369 sentences left
# 368 sentences left
# 367 sentences left
# 366 sentences left
# 365 sentences left
# 364 sentences left
# 363 sentences left
# 362 sentences left
# 361 sentences left
# 360 sentences left
# 359 sentences left
# 358 sentences left
# 357 sentences left
# 356 sentences left
# 355 sentences left
# 354 sentences left
# 353 sentences left
# 352 sentences left
# 351 sentences left
# 350 sentences left
# 349 sentences left
# 348 sentences left
# 347 sentences left
# 346 sentences left
# 345 sentences left
# 344 sentences left
# 343 sentences left
# 342 sentences left
# 341 sentences left
# 340 sentences left
# 339 sentences left
# 338 sentences left
# 337 sentences left
# 336 sentences left
# 335 sentences left
# 334 sentences left
# 333 sentences left
# 332 sentences left
# 331 sentences left
# 330 sentences left
# 329 sentences left
# 328 sentences left
# 327 sentences left
# 326 sentences left
# 325 sentences left
# 324 sentences left
# 323 sentences left
# 322 sentences left
# 321 sentences left
# 320 sentences left
# 319 sentences left
# 318 sentences left
# 317 sentences left
# 316 sentences left
# 315 sentences left
# 314 sentences left
# 313 sentences left
# 312 sentences left
# 311 sentences left
# 310 sentences left
# 309 sentences left
# 308 sentences left
# 307 sentences left
# 306 sentences left
# 305 sentences left
# 304 sentences left
# 303 sentences left
# 302 sentences left
# 301 sentences left
# 300 sentences left
# 299 sentences left
# 298 sentences left
# 297 sentences left
# 296 sentences left
# 295 sentences left
# 294 sentences left
# 293 sentences left
# 292 sentences left
# 291 sentences left
# 290 sentences left
# 289 sentences left
# 288 sentences left
# 287 sentences left
# 286 sentences left
# 285 sentences left
# 284 sentences left
# 283 sentences left
# 282 sentences left
# 281 sentences left
# 280 sentences left
# 279 sentences left
# 278 sentences left
# 277 sentences left
# 276 sentences left
# 275 sentences left
# 274 sentences left
# 273 sentences left
# 272 sentences left
# 271 sentences left
# 270 sentences left
# 269 sentences left
# 268 sentences left
# 267 sentences left
# 266 sentences left
# 265 sentences left
# 264 sentences left
# 263 sentences left
# 262 sentences left
# 261 sentences left
# 260 sentences left
# 259 sentences left
# 258 sentences left
# 257 sentences left
# 256 sentences left
# 255 sentences left
# 254 sentences left
# 253 sentences left
# 252 sentences left
# 251 sentences left
# 250 sentences left
# 249 sentences left
# 248 sentences left
# 247 sentences left
# 246 sentences left
# 245 sentences left
# 244 sentences left
# 243 sentences left
# 242 sentences left
# 241 sentences left
# 240 sentences left
# 239 sentences left
# 238 sentences left
# 237 sentences left
# 236 sentences left
# 235 sentences left
# 234 sentences left
# 233 sentences left
# 232 sentences left
# 231 sentences left
# 230 sentences left
# 229 sentences left
# 228 sentences left
# 227 sentences left
# 226 sentences left
# 225 sentences left
# 224 sentences left
# 223 sentences left
# 222 sentences left
# 221 sentences left
# 220 sentences left
# 219 sentences left
# 218 sentences left
# 217 sentences left
# 216 sentences left
# 215 sentences left
# 214 sentences left
# 213 sentences left
# 212 sentences left
# 211 sentences left
# 210 sentences left
# 209 sentences left
# 208 sentences left
# 207 sentences left
# 206 sentences left
# 205 sentences left
# 204 sentences left
# 203 sentences left
# 202 sentences left
# 201 sentences left
# 200 sentences left
# 199 sentences left
# 198 sentences left
# 197 sentences left
# 196 sentences left
# 195 sentences left
# 194 sentences left
# 193 sentences left
# 192 sentences left
# 191 sentences left
# 190 sentences left
# 189 sentences left
# 188 sentences left
# 187 sentences left
# 186 sentences left
# 185 sentences left
# 184 sentences left
# 183 sentences left
# 182 sentences left
# 181 sentences left
# 180 sentences left
# 179 sentences left
# 178 sentences left
# 177 sentences left
# 176 sentences left
# 175 sentences left
# 174 sentences left
# 173 sentences left
# 172 sentences left
# 171 sentences left
# 170 sentences left
# 169 sentences left
# 168 sentences left
# 167 sentences left
# 166 sentences left
# 165 sentences left
# 164 sentences left
# 163 sentences left
# 162 sentences left
# 161 sentences left
# 160 sentences left
# 159 sentences left
# 158 sentences left
# 157 sentences left
# 156 sentences left
# 155 sentences left
# 154 sentences left
# 153 sentences left
# 152 sentences left
# 151 sentences left
# 150 sentences left
# 149 sentences left
# 148 sentences left
# 147 sentences left
# 146 sentences left
# 145 sentences left
# 144 sentences left
# 143 sentences left
# 142 sentences left
# 141 sentences left
# 140 sentences left
# 139 sentences left
# 138 sentences left
# 137 sentences left
# 136 sentences left
# 135 sentences left
# 134 sentences left
# 133 sentences left
# 132 sentences left
# 131 sentences left
# 130 sentences left
# 129 sentences left
# 128 sentences left
# 127 sentences left
# 126 sentences left
# 125 sentences left
# 124 sentences left
# 123 sentences left
# 122 sentences left
# 121 sentences left
# 120 sentences left
# 119 sentences left
# 118 sentences left
# 117 sentences left
# 116 sentences left
# 115 sentences left
# 114 sentences left
# 113 sentences left
# 112 sentences left
# 111 sentences left
# 110 sentences left
# 109 sentences left
# 108 sentences left
# 107 sentences left
# 106 sentences left
# 105 sentences left
# 104 sentences left
# 103 sentences left
# 102 sentences left
# 101 sentences left
# 100 sentences left
# 99 sentences left
# 98 sentences left
# 97 sentences left
# 96 sentences left
# 95 sentences left
# 94 sentences left
# 93 sentences left
# 92 sentences left
# 91 sentences left
# 90 sentences left
# 89 sentences left
# 88 sentences left
# 87 sentences left
# 86 sentences left
# 85 sentences left
# 84 sentences left
# 83 sentences left
# 82 sentences left
# 81 sentences left
# 80 sentences left
# 79 sentences left
# 78 sentences left
# 77 sentences left
# 76 sentences left
# 75 sentences left
# 74 sentences left
# 73 sentences left
# 72 sentences left
# 71 sentences left
# 70 sentences left
# 69 sentences left
# 68 sentences left
# 67 sentences left
# 66 sentences left
# 65 sentences left
# 64 sentences left
# 63 sentences left
# 62 sentences left
# 61 sentences left
# 60 sentences left
# 59 sentences left
# 58 sentences left
# 57 sentences left
# 56 sentences left
# 55 sentences left
# 54 sentences left
# 53 sentences left
# 52 sentences left
# 51 sentences left
# 50 sentences left
# 49 sentences left
# 48 sentences left
# 47 sentences left
# 46 sentences left
# 45 sentences left
# 44 sentences left
# 43 sentences left
# 42 sentences left
# 41 sentences left
# 40 sentences left
# 39 sentences left
# 38 sentences left
# 37 sentences left
# 36 sentences left
# 35 sentences left
# 34 sentences left
# 33 sentences left
# 32 sentences left
# 31 sentences left
# 30 sentences left
# 29 sentences left
# 28 sentences left
# 27 sentences left
# 26 sentences left
# 25 sentences left
# 24 sentences left
# 23 sentences left
# 22 sentences left
# 21 sentences left
# 20 sentences left
# 19 sentences left
# 18 sentences left
# 17 sentences left
# 16 sentences left
# 15 sentences left
# 14 sentences left
# 13 sentences left
# 12 sentences left
# 11 sentences left
# 10 sentences left
# 9 sentences left
# 8 sentences left
# 7 sentences left
# 6 sentences left
# 5 sentences left
# 4 sentences left
# 3 sentences left
# 2 sentences left
# 1 sentences left
# 0 sentences left

# %%
with open('./back.pkl', 'wb') as file:
    pickle.dump(back, file)

# %%
with open('./back.pkl','rb') as file:
    back = pickle.load(file)

# %% [markdown]
# # Performing EDA

# %%
text = "start each day with positive thoughts and make your day"

#Create instances
wordnet_aug = WordNetAugmenter()
embed_aug = EmbeddingAugmenter()
eda_aug = EasyDataAugmenter()
charswap_aug = CharSwapAugmenter()
checklist_aug = CheckListAugmenter()
# clare_aug = CLAREAugmenter()

#print augmented text
print(wordnet_aug.augment(text))
print(embed_aug.augment(text))
print(eda_aug.augment(text))
print(charswap_aug.augment(text))
print(checklist_aug.augment(text))
# print(clare_aug.augment(text))
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/meetbanthia/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# textattack: Downloading https://textattack.s3.amazonaws.com/word_embeddings/paragramcf.
# 100%|██████████| 481M/481M [24:04<00:00, 333kB/s]
# textattack: Unzipping file /Users/meetbanthia/.cache/textattack/tmp6o1oer9n.zip to /Users/meetbanthia/.cache/textattack/word_embeddings/paragramcf.
# textattack: Successfully saved word_embeddings/paragramcf to cache.
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/meetbanthia/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ['starting each day with positive thoughts and make your day']
# ['launched each day with positive thoughts and make your day']
# ['start each day with positive thoughts and make day your', 'start day with positive thoughts and make your day', 'start each day with positive view and make your day', 'start each day with mentation positive thoughts and make your day']
# ['start each day with psitive thoughts and make your day']
# pytorch_model.bin:   0%|          | 0.00/432M [00:00<?, ?B/s]
# 2024-01-25 23:39:10,288 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# ['start each day with positive thoughts and make your day']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 17
#      15 print(charswap_aug.augment(text))
#      16 print(checklist_aug.augment(text))
# ---> 17 print(clare_aug.augment(text))
#
# File ~/miniconda3/envs/torch/lib/python3.9/site-packages/textattack/augmentation/augmenter.py:125, in Augmenter.augment(self, text)
#     122 words_swapped = len(current_text.attack_attrs["modified_indices"])
#     124 while words_swapped < num_words_to_swap:
# --> 125     transformed_texts = self.transformation(
#     126         current_text, self.pre_transformation_constraints
#     127     )
#     129     # Get rid of transformations we already have
#     130     transformed_texts = [
#     131         t for t in transformed_texts if t not in all_transformed_texts
#     132     ]
#
# File ~/miniconda3/envs/torch/lib/python3.9/site-packages/textattack/transformations/composite_transformation.py:39, in CompositeTransformation.__call__(self, *args, **kwargs)
#      37 new_attacked_texts = set()
#      38 for transformation in self.transformations:
# ---> 39     new_attacked_texts.update(transformation(*args, **kwargs))
#      40 return list(new_attacked_texts)
#
# File ~/miniconda3/envs/torch/lib/python3.9/site-packages/textattack/transformations/transformation.py:57, in Transformation.__call__(self, current_text, pre_transformation_constraints, indices_to_modify, shifted_idxs, return_indices)
#      54 if return_indices:
#      55     return indices_to_modify
# ---> 57 transformed_texts = self._get_transformations(current_text, indices_to_modify)
#      58 for text in transformed_texts:
#      59     text.attack_attrs["last_transformation"] = self
#
# File ~/miniconda3/envs/torch/lib/python3.9/site-packages/textattack/transformations/word_merges/word_merge_masked_lm.py:162, in WordMergeMaskedLM._get_transformations(self, current_text, indices_to_modify)
#     160 indices_to_modify = list(indices_to_modify)
#     161 # find indices that are suitable to merge
# --> 162 token_tags = [
#     163     current_text.pos_of_word_index(i) for i in range(current_text.num_words)
#     164 ]
#     165 merge_indices = find_merge_index(token_tags)
#     166 merged_words = self._get_merged_words(current_text, merge_indices)
#
# File ~/miniconda3/envs/torch/lib/python3.9/site-packages/textattack/transformations/word_merges/word_merge_masked_lm.py:163, in <listcomp>(.0)
#     160 indices_to_modify = list(indices_to_modify)
#     161 # find indices that are suitable to merge
#     162 token_tags = [
# --> 163     current_text.pos_of_word_index(i) for i in range(current_text.num_words)
#     164 ]
#     165 merge_indices = find_merge_index(token_tags)
#     166 merged_words = self._get_merged_words(current_text, merge_indices)
#
# File ~/miniconda3/envs/torch/lib/python3.9/site-packages/textattack/shared/attacked_text.py:141, in AttackedText.pos_of_word_index(self, desired_word_idx)
#     139     textattack.shared.utils.flair_tag(sentence)
#     140     self._pos_tags = sentence
# --> 141 flair_word_list, flair_pos_list = textattack.shared.utils.zip_flair_result(
#     142     self._pos_tags
#     143 )
#     145 for word_idx, word in enumerate(self.words):
#     146     assert (
#     147         word in flair_word_list
#     148     ), "word absent in flair returned part-of-speech tags"
#
# File ~/miniconda3/envs/torch/lib/python3.9/site-packages/textattack/shared/utils/strings.py:245, in zip_flair_result(pred, tag_type)
#     243 word_list.append(token.text)
#     244 if "pos" in tag_type:
# --> 245     pos_list.append(token.annotation_layers["upos"][0]._value)
#     246 elif tag_type == "ner":
#     247     pos_list.append(token.get_label("ner"))
#
# KeyError: 'upos'

# %% [markdown]
# # Perform synonym replacement on back

# %%
aug = [wordnet_aug.augment(text)[0] for text in back]

# %%
labels = [item[0] for item in (df.values).tolist()]
merged_list = list(zip(labels, aug))
extradf = pd.DataFrame(merged_list, columns=['label', 'sentence'])

# %%
label_counts = extradf['label'].value_counts()
print(label_counts)

#Initial data
'''
STATUTE     176
RLC         171
COUNSEL     128
ARG         121
JUDGE        64
CITATION     60
NAME         59
'''
# Out:
# label
# STATUTE     176
# RLC         171
# COUNSEL     128
# ARG         121
# JUDGE        64
# CITATION     60
# NAME         59
# Name: count, dtype: int64
# '\nSTATUTE     176\nRLC         171\nCOUNSEL     128\nARG         121\nJUDGE        64\nCITATION     60\nNAME         59\n'

# %%
rows_to_delete = extradf[extradf['label'] == 'STATUTE']
rows_to_keep = 64
selected_rows1 = rows_to_delete.sample(n=rows_to_keep, random_state=42)

rows_to_delete = extradf[extradf['label'] == 'RLC']
rows_to_keep = 69
selected_rows2 = rows_to_delete.sample(n=rows_to_keep, random_state=42)

rows_to_delete = extradf[extradf['label'] == 'COUNSEL']
rows_to_keep = 112
selected_rows3 = rows_to_delete.sample(n=rows_to_keep, random_state=42)

rows_to_delete = extradf[extradf['label'] == 'ARG']
rows_to_keep = 119
selected_rows4 = rows_to_delete.sample(n=rows_to_keep, random_state=42)

selected = (selected_rows1.index).to_list() + (selected_rows2.index).to_list() + (selected_rows3.index).to_list() + (selected_rows4.index).to_list() + (extradf[extradf['label'] == 'JUDGE'].index).to_list() + (extradf[extradf['label'] == 'CITATION'].index).to_list() + (extradf[extradf['label'] == 'NAME'].index).to_list()

selected_df = extradf.iloc[selected].reset_index(drop=True)

# %%
selected_df
# Out:
#        label                                           sentence
# 0    STATUTE  (2) Where a farmer has paid a creditor twice t...
# 1    STATUTE  Article 5 of the Ordinance preface several ame...
# 2    STATUTE  It was urged that section 3(b) of the Jaipur A...
# 3    STATUTE  Section 21 of the Act render that, if the Reve...
# 4    STATUTE  Article 13, paragraph 1, with which we are int...
# ..       ...                                                ...
# 542     NAME  Mahant Pragdasji Guru... fivesome Patel Ishwar...
# 543     NAME    Amjad Khan v. The commonwealth on 20 March 1952
# 544     NAME  Raja Bhupendra Narain Singha... quintuplet Mah...
# 545     NAME  Gnanambal Ammal vs tonne. Raju Ayyar and other...
# 546     NAME  Yeswant Deorao Deshmukh fivesome Walchand Ramc...
#
# [547 rows x 2 columns]

# %%
# Load the DataFrame from CSV
newdf = pd.read_csv('final.csv', sep=',', names=['label', 'sentence'])
newdf = newdf.drop(0)

# Select rows based on conditions
rows_to_delete1 = newdf[newdf['label'] == 'RPC']
selected_rows1 = rows_to_delete1.sample(n=2, random_state=42)
newdf = newdf.drop(selected_rows1.index)

rows_to_delete2 = newdf[newdf['label'] == 'PRECEDENT']
selected_rows2 = rows_to_delete2.sample(n=31, random_state=42)
newdf = newdf.drop(selected_rows2.index)

rows_to_delete3 = newdf[newdf['label'] == 'REASONING']
selected_rows3 = rows_to_delete3.sample(n=3051, random_state=42)
newdf = newdf.drop(selected_rows3.index)

rows_to_delete4 = newdf[newdf['label'] == 'FACTS']
selected_rows4 = rows_to_delete4.sample(n=1218, random_state=42)
newdf = newdf.drop(selected_rows4.index)

newdf = newdf.drop(newdf[newdf['label'] == 'STATUTE'].index)
newdf = newdf.drop(newdf[newdf['label'] == 'RLC'].index)
newdf = newdf.drop(newdf[newdf['label'] == 'COUNSEL'].index)
newdf = newdf.drop(newdf[newdf['label'] == 'ARG'].index)
newdf = newdf.drop(newdf[newdf['label'] == 'JUDGE'].index)
newdf = newdf.drop(newdf[newdf['label'] == 'CITATION'].index)
newdf = newdf.drop(newdf[newdf['label'] == 'NAME'].index)

newdf = newdf.reset_index(drop=True)

# %%
# add this selected_df with df and create a new df
result_df = pd.concat([newdf, selected_df], axis=0, ignore_index=True)

# %%
label_counts = result_df['label'].value_counts()
print(label_counts)
# Out:
# label
# FACTS        240
# REASONING    240
# RPC          240
# PRECEDENT    240
# ARG          119
# COUNSEL      112
# RLC           69
# STATUTE       64
# JUDGE         64
# CITATION      60
# NAME          59
# Name: count, dtype: int64

# %%
final_df = pd.concat([df, result_df], axis=0, ignore_index=True)

# %%
label_counts = final_df['label'].value_counts()
print(label_counts)
# Out:
# label
# STATUTE      240
# COUNSEL      240
# RLC          240
# ARG          240
# FACTS        240
# REASONING    240
# RPC          240
# PRECEDENT    240
# JUDGE        128
# CITATION     120
# NAME         118
# Name: count, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
final_df.to_csv('final_df.csv', index=False)

# %%
df = pd.read_csv('final_df.csv',sep=',',names=['label','sentence'])
df = df.drop(0)
print(len(df))
df = df.dropna()
print(len(df))
# Out:
# 2286
# 2284

# %%
len(df)
# Out:
# 2284

# %%
texts =  (df['sentence']).to_list()
texts = pp.preprocess(texts)

# %%
labels =  (df['label']).to_list()
merged_list = list(zip(labels, texts))
pp_df = pd.DataFrame(merged_list, columns=['label', 'sentence'])

# %%
pp_df.to_csv('pp_df.csv', index=False)

# %% [markdown]
# # Sentence Embedding

# %%
import torch

import os

from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("law-ai/InLegalBERT")
model = AutoModel.from_pretrained("law-ai/InLegalBERT")
# Out:
# Some weights of the model checkpoint at law-ai/InLegalBERT were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
pp_df = pd.read_csv('pp_df.csv',sep=',',names=['label','sentence'])
pp_df = pp_df.drop(0)
pp_df = pp_df.dropna()

# %%
def get_sentence_embeddings(sentences):
    # Tokenize the sentences
    encoded_inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

    # Forward pass through the BERT model
    with torch.no_grad():
        outputs = model(**encoded_inputs)
        sentence_embeddings = outputs.last_hidden_state[:,0,:]  # Average pooling

    return sentence_embeddings

# %%
textvect = get_sentence_embeddings((pp_df['sentence']).to_list())

# %%
with open('./intermediate/textvect.pickle', 'wb') as file:
    pickle.dump(textvect, file)
